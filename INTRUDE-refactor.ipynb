# %% [markdown]
# ### 1300 3 max score

# %%
# %run -i 'model/Classify.py'
# %matplotlib inline
# Out:
# --------------------------
# Size of Dataset: training_set 117740 testing_set 115521 feature_length= 33
# ------ model:  boost ------
# n_estimators: 1300 max_depth: 3
# 0.9922456602149852
# Mean Accuracy: 0.9941309372321916
# Average precision score: 0.7843
# F1 score: 0.6968
# 0.9941309372321916	0.7842821484345454	0.6967799642218246

# %% [markdown]
# ## 200-800

# %%
# %run -i 'model/Classify.py'
# %matplotlib inline
# Out:
# --------------------------
# Size of Dataset: training_set 117740 testing_set 115521 feature_length= 33
# ------ model:  boost ------
# n_estimators: 100 max_depth: 2
# 0.9913113748363862
# Mean Accuracy: 0.992269803758624
# Average precision score: 0.6565
# F1 score: 0.3698
# 0.992269803758624	0.6565441519895356	0.36979534227240646
# n_estimators: 100 max_depth: 3
# 0.9913878140885195
# Mean Accuracy: 0.992936349235204
# Average precision score: 0.7074
# F1 score: 0.4617
# 0.992936349235204	0.7074374102706016	0.46174142480211083
# n_estimators: 100 max_depth: 4
# 0.9912689155986341
# Mean Accuracy: 0.9929450056699648
# Average precision score: 0.7173
# F1 score: 0.4628
# 0.9929450056699648	0.7172901576775979	0.46275543836519445
# n_estimators: 100 max_depth: 5
# 0.991736047647532
# Mean Accuracy: 0.9932306680170705
# Average precision score: 0.7353
# F1 score: 0.4981
# 0.9932306680170705	0.73533227962518	0.49807445442875475
# n_estimators: 100 max_depth: 6
# 0.9919653632396074
# ...

# %% [markdown]
# 900-1100

# %%
# %run -i 'model/Classify.py'
# %matplotlib inline
# Out:
# --------------------------
# Size of Dataset: training_set 117740 testing_set 115521 feature_length= 33
# ------ model:  boost ------
# n_estimators: 900 max_depth: 3
# 0.9922371658427522
# Mean Accuracy: 0.9941569065364739
# Average precision score: 0.7823
# F1 score: 0.6961
# 0.9941569065364739	0.7823169326720578	0.6960828455650607
# n_estimators: 900 max_depth: 4
# 0.9920927831536528
# Mean Accuracy: 0.993914526363172
# Average precision score: 0.7781
# F1 score: 0.6896
# 0.993914526363172	0.7780798579197363	0.6896247240618101
# n_estimators: 1000 max_depth: 3
# 0.9924325118803319
# Mean Accuracy: 0.99411362436267
# Average precision score: 0.7834
# F1 score: 0.6945
# 0.99411362436267	0.7834238259521467	0.6945193171608266
# n_estimators: 1000 max_depth: 4
# 0.9920757944089414
# Mean Accuracy: 0.9939404956674543
# Average precision score: 0.7790
# F1 score: 0.6911
# 0.9939404956674543	0.7790029799047702	0.6910856134157105
# n_estimators: 1100 max_depth: 3
# 0.9922796330155232
# ...

# %% [markdown]
# ## 1200-1800
# ### 1300 3 max

# %%
# %run -i 'model/Classify.py'
# %matplotlib inline
# Out:
# --------------------------
# Size of Dataset: training_set 117740 testing_set 115521 feature_length= 33
# ------ model:  boost ------
# n_estimators: 1200 max_depth: 3
# 0.9923560726282906
# Mean Accuracy: 0.9941395936669524
# Average precision score: 0.7843
# F1 score: 0.6965
# 0.9941395936669524	0.7842635032498664	0.6965486329000448
# n_estimators: 1200 max_depth: 4
# 0.9920078498899203
# Mean Accuracy: 0.9938625877546073
# Average precision score: 0.7770
# F1 score: 0.6886
# 0.9938625877546073	0.7770461701187352	0.6886253842775583
# n_estimators: 1300 max_depth: 3
# 0.9922456602149852
# Mean Accuracy: 0.9941309372321916
# Average precision score: 0.7843
# F1 score: 0.6968
# 0.9941309372321916	0.7842821484345454	0.6967799642218246
# n_estimators: 1300 max_depth: 4
# 0.9919993573209794
# Mean Accuracy: 0.9937933362765211
# Average precision score: 0.7767
# F1 score: 0.6857
# 0.9937933362765211	0.7767439477397463	0.6856641823761509
# n_estimators: 1400 max_depth: 3
# ...
